# %% [markdown]
# ## Seaborn Exercises

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
import pandas as pd
import scipy.stats as s
sns.jointplot(x="fare", y="age", data=titanic, xlim=(-100,600), stat_func=s.pearsonr)
# Out:
# C:\Users\rstsa\anaconda3\lib\site-packages\seaborn\axisgrid.py:1848: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
ax = sns.distplot(titanic["fare"],kde=False,color="red", bins=30, hist_kws={"rwidth":100})
ax.set_xlim(-2, 600)
ax.set_ylim(0,500)
ax.margins(x=0)

# %%
ax = sns.boxplot(x="class", y="age", data=titanic, palette="rainbow")
ax.set_ylim(0,80)
# Out:
# (0, 80)

# %%
sns.swarmplot(x="class",y="age", data=titanic, palette="Set2")
# Out:
# C:\Users\rstsa\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\rstsa\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
ax = sns.countplot(x="sex", data=titanic, palette="deep")
ax.set_ylim(0,600)
# Out:
# (0, 600)

# %%
sns.heatmap(titanic.corr(), cmap="coolwarm")
plt.title("titanic.corr()")
# Out:
# Text(0.5, 1, 'titanic.corr()')

# %%
a = sns.FacetGrid(data=titanic, col="sex", xlim=(0,80), ylim=(0,120))
a.map(sns.distplot, "age", kde=False, bins=10)
